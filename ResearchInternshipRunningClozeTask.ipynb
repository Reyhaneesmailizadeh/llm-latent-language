# %%
# !rm -rf llm-latent-language
# !git clone https://github.com/Reyhaneesmailizadeh/llm-latent-language/

# !pip install -r llm-latent-language/requirements.txt
# Out:
# Cloning into 'llm-latent-language'...
# remote: Enumerating objects: 258, done.
# remote: Counting objects: 100% (142/142), done.
# remote: Compressing objects: 100% (75/75), done.
# remote: Total 258 (delta 83), reused 91 (delta 57), pack-reused 116 (from 1)
# Receiving objects: 100% (258/258), 3.18 MiB | 9.71 MiB/s, done.
# Resolving deltas: 100% (120/120), done.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 MB 11.5 MB/s eta 0:00:0000:0100:01
# ...

# %%
# %cd llm-latent-language
# Out:
# /kaggle/working/llm-latent-language

# %%
# !ls
# Out:
# Cloze.ipynb  Translation.ipynb	output-50.png  requirements.txt
# R	     data		output.png     utils.py
# README.md    llamawrapper.py	plot_grid.sh

# %%
# !pip install -U bitsandbytes

# %%
# !papermill Cloze.ipynb out.ipynb -p target_lang fr
# Out:
# Executing:  83%|█████████████████████████     | 15/18 [02:16<00:30, 10.17s/cell]
